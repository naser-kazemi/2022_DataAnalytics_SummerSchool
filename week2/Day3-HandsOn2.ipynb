# %% [markdown]
# <img src="../assets/logo3.png" width="200" height="200" align = center>
#
# <div style="display:block"><br><br>
#     <div style="display:block" align=left display=block>
#         <font size=5><b>HandsOn 5 - Advanced Pandas in Action</b></font><br>
#         <hr/>
#
# </div>
#
# <pre>
# .
# ├── Importing Modules/Libraries
# │
# ├── Load data from local disk
# │
# ├── Working with clean Dataframe
# │
# ├── Create Pivot Tables from datafarme
# │
# ├── Groupby Object
# │
# └── Merge and Join
# </pre>

# %% [markdown]
# Pandas is a library for data analysis built on top of the Python programming language. A library (also called a package) is a collection of code for solving problems in a specific field of endeavor. Pandas is a toolbox for data manipulation operations: sorting, filtering, cleaning, deduping, aggregating, pivoting, and more. The epicenter of Python’s vast data science ecosystem, pandas pairs well with other libraries for statistics, natural language processing, machine learning, data visualization, and more.
#
# The sections marked with a Thinking Emoji (💭) are those which you need to read and answer. All right, without further ado let's get started!
#
# In this handsOn you are going to work on the dataset that you have cleaned in the last handsOn.

# %% [markdown]
# ## Importing Modules/Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ### 📖 Load data from local disk
# First, we need to load the data from local disk as a Pandas dataframe.
# - use the `clean_adults_income.csv` dataset from last handson!

# %% [markdown]
# **Write the answer below:**

# %%
df = pd.read_csv('clean_adults_income.csv')

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# ### 📖 Working with clean Dataframe
# Now you have cleaned the dataframe. in this Section, we are going to work with this clean dataframe.
#
# #### 💭 Questions
# - rename the `hours-per-week` to `hours`.
# - print unique values of `education` and `income` column.
# - count the number of each  unique value in `race` column
# - calculate mean hour for persons of `white` race and with income `less than 50K`

# %% [markdown]
# **Write the answer below:**

# %%
# rename column name
df = df.rename(columns={'hours-per-week':'hours'})
df.head()
# Out:
#     age         workclass    fnlwgt     education  educational-num  \
# 0  38.0           Private   89814.0       HS-grad              9.0
# 1  28.0         Local-gov  336951.0    Assoc-acdm             12.0
# 2  34.0           Private  198693.0          10th              6.0
# 3  63.0  Self-emp-not-inc  104626.0   Prof-school             15.0
# 4  24.0           Private  369667.0  Some-college             10.0
#
#         occupation   relationship   race  gender  capital-gain  capital-loss  \
# 0  Farming-fishing        Husband  White    Male           0.0           0.0
# 1  Protective-serv        Husband  White    Male           0.0           0.0
# 2    Other-service  Not-in-family  White    Male           0.0           0.0
# 3   Prof-specialty        Husband  White    Male        3103.0           0.0
# 4    Other-service      Unmarried  White  Female           0.0           0.0
#
#    hours native-country income  age_category  hours_in_year  income_values  \
# 0   50.0  United-States  <=50K             3         2850.0          50000
# 1   40.0  United-States   >50K             2         2280.0          50000
# 2   30.0  United-States  <=50K             3         1710.0          50000
# 3   32.0  United-States   >50K             4         1824.0          50000
# 4   40.0  United-States  <=50K             2         2280.0          50000
#
#    average_hour_income
# 0          1000.000000
# 1          1250.000000
# 2          1666.666667
# 3          1562.500000
# 4          1250.000000

# %%
# print unique values
df.nunique()
# Out:
# age                       73
# workclass                  7
# fnlwgt                 23184
# education                 16
# educational-num           16
# occupation                14
# relationship               6
# race                       5
# gender                     2
# capital-gain             121
# capital-loss              95
# hours                     95
# native-country            41
# income                     2
# age_category               4
# hours_in_year             95
# income_values              1
# average_hour_income       95
# dtype: int64

# %%
for col in df:
#    724.63768116   574.71264368   515.46391753   609.75609756
#    549.45054945   617.28395062   526.31578947]

# %%
#  count values
df.value_counts()
# Out:
# age   workclass         fnlwgt    education     educational-num  occupation         relationship   race                gender  capital-gain  capital-loss  hours  native-country  income  age_category  hours_in_year  income_values  average_hour_income
# 25.0  Private           195994.0  1st-4th       2.0              Priv-house-serv    Not-in-family  White               Female  0.0           0.0           40.0   Guatemala       <=50K   2             2280.0         50000          1250.000000            2
# 23.0  Private           250630.0  Bachelors     13.0             Sales              Not-in-family  White               Female  0.0           0.0           40.0   United-States   <=50K   2             2280.0         50000          1250.000000            2
#                         239539.0  HS-grad       9.0              Machine-op-inspct  Own-child      Asian-Pac-Islander  Male    0.0           0.0           40.0   Philippines     <=50K   2             2280.0         50000          1250.000000            2
# 46.0  Private           173243.0  HS-grad       9.0              Craft-repair       Husband        White               Male    0.0           0.0           40.0   United-States   <=50K   4             2280.0         50000          1250.000000            2
# 25.0  Private           308144.0  Bachelors     13.0             Craft-repair       Not-in-family  White               Male    0.0           0.0           40.0   Mexico          <=50K   2             2280.0         50000          1250.000000            2
#                                                                                                                                                                                                                                                             ..
# 31.0  Private           210008.0  HS-grad       9.0              Sales              Own-child      White               Female  0.0           0.0           40.0   United-States   <=50K   3             2280.0         50000          1250.000000            1
#                         209538.0  Some-college  10.0             Adm-clerical       Husband        White               Male    0.0           0.0           55.0   United-States   <=50K   3             3135.0         50000          909.090909             1
#                                   10th          6.0              Machine-op-inspct  Husband        White               Male    0.0           0.0           40.0   United-States   <=50K   3             2280.0         50000          1250.000000            1
#                                                                  Craft-repair       Husband        White               Male    0.0           0.0           40.0   United-States   <=50K   3             2280.0         50000          1250.000000            1
# 90.0  Self-emp-not-inc  155981.0  Bachelors     13.0             Prof-specialty     Husband        White               Male    10566.0       0.0           50.0   United-States   <=50K   4             2850.0         50000          1000.000000            1
# Length: 36568, dtype: int64

# %%
# calculate mean hour hour for the condition
hours_based_on_condition = df[(df.race == 'White') & (df.income == '<=50K')].hours
hours_based_on_condition.mean()
# Out:
# 39.58229539283713

# %% [markdown]
# --------------

# %% [markdown]
# ### 📖 Create Pivot Tables from datafarme
# A pivot table aggregates a column’s values and groups the results by using other columns’ values. The word aggregate describes a summary computation that involves multiple values. Example aggregations include average, sum, median, and count. A pivot table in pandas is similar to the Pivot Table feature in Microsoft Excel.
#
# #### 💭 Questions
# - 1- use `mean` aggregation function to calculate the average for columns based on unique each `education` as an index. explain the results in a markdown cell.
# - 2- with considering `education` as an index, calculate `maximum` of hours for each `income`. Can we conclude that high incomes always require more working hours?
# - 3- (Bonus) calculate `min` age for each `income` and each `gender` with considering `race` as index.
# - 4- (Bonus) calculate `mean` hours for each `race`  and each `income` with considering `occupation` as an index. Can you tell us what the `NaNs` are in the result?

# %% [markdown]
# **Write the answer below:**

# %%
# 1
mean_pivot_tabel = df.pivot_table(index=['education'], aggfunc='mean')
mean_pivot_tabel
# Out:
#                     age  age_category  average_hour_income  capital-gain  \
# education
# 10th          38.087437      2.881407          1716.957814    158.272362
# 11th          32.135514      2.439252          1982.108884    196.985981
# 12th          32.234783      2.469565          1730.634244    178.447826
# 1st-4th       45.305556      3.455556          1488.549679     96.883333
# 5th-6th       42.953930      3.303523          1568.663810    441.867209
# 7th-8th       48.234206      3.511556          1561.569896    264.269646
# 9th           40.123845      3.096118          1458.464535    359.225508
# Assoc-acdm    37.621800      3.138728          1405.748662    588.047894
# Assoc-voc     38.507069      3.174807          1323.652641    793.613111
# Bachelors     38.625810      3.169365          1344.880244   1764.469236
# Doctorate     47.191489      3.702128          1392.782191   5668.992908
# HS-grad       38.737841      3.110843          1377.885101    569.381246
# Masters       43.703178      3.542298          1303.102177   2567.753056
# Preschool     40.568966      3.224138          1589.923984   1047.517241
# Prof-school   44.589862      3.565284          1237.618629  10972.168971
# Some-college  36.136421      2.956576          1511.641779    562.552209
#
#               capital-loss  educational-num         fnlwgt      hours  \
# education
# 10th             62.304523              6.0  197347.956784  37.559799
# 11th             50.762461              7.0  195618.691589  34.300623
# 12th             26.369565              8.0  196849.856522  35.826087
# 1st-4th          66.000000              2.0  245166.483333  39.461111
# 5th-6th          76.737127              3.0  234655.181572  38.184282
# 7th-8th          53.180277              4.0  191385.904468  39.906009
# 9th              47.011091              5.0  202795.443623  39.099815
# Assoc-acdm       93.340215             12.0  193908.645747  41.423617
# Assoc-voc        72.705656             11.0  177938.007712  41.971722
# Bachelors       125.822863             13.0  186871.306671  42.816710
# Doctorate       212.940898             16.0  185657.434988  47.153664
# HS-grad          66.737175              9.0  188143.214191  41.047885
# Masters         173.731051             14.0  181264.658680  44.150611
# Preschool        58.465517              1.0  240330.086207  36.793103
# Prof-school     239.921659             15.0  185285.901690  48.006144
# Some-college     76.261923             10.0  190410.130899  39.551958
#
#               hours_in_year  income_values
# education
# 10th            2140.908543          50000
# 11th            1955.135514          50000
# 12th            2042.086957          50000
# 1st-4th         2249.283333          50000
# 5th-6th         2176.504065          50000
# 7th-8th         2274.642527          50000
# 9th             2228.689464          50000
# Assoc-acdm      2361.146160          50000
# Assoc-voc       2392.388175          50000
# Bachelors       2440.552461          50000
# Doctorate       2687.758865          50000
# HS-grad         2339.729430          50000
# Masters         2516.584841          50000
# Preschool       2097.206897          50000
# Prof-school     2736.350230          50000
# Some-college    2254.461596          50000

# %% [markdown]
# !Expalain results here!

# %%
# 2
max_pivot_tabel = df.pivot_table(index=['education'], columns=['income'], values=['hours'], aggfunc='max')
max_pivot_tabel
# Out:
#              hours
# income       <=50K  >50K
# education
# 10th          99.0  99.0
# 11th          99.0  99.0
# 12th          99.0  84.0
# 1st-4th       96.0  67.0
# 5th-6th       75.0  67.0
# 7th-8th       99.0  99.0
# 9th           99.0  70.0
# Assoc-acdm    99.0  99.0
# Assoc-voc     99.0  99.0
# Bachelors     99.0  99.0
# Doctorate     99.0  99.0
# HS-grad       99.0  99.0
# Masters       99.0  99.0
# Preschool     75.0  40.0
# Prof-school   99.0  99.0
# Some-college  99.0  99.0

# %%
# 3 (Bonus)
min_age_pivot_tabel = df.pivot_table(index=['race'], columns=['income', 'gender'], values=['age'], aggfunc='min')
min_age_pivot_tabel
# Out:
#                       age
# income              <=50K         >50K
# gender             Female  Male Female  Male
# race
# Amer-Indian-Eskimo   17.0  17.0   21.0  27.0
# Asian-Pac-Islander   18.0  18.0   26.0  23.0
# Black                17.0  17.0   21.0  20.0
# Other                17.0  17.0   29.0  27.0
# White                17.0  17.0   19.0  21.0

# %%
# 4 (Bonus)
mean_hours_pivot_tabel = df.pivot_table(index=['occupation'], columns=['race', 'income'], values=['hours'], aggfunc='mean')
mean_hours_pivot_tabel
# Out:
#                                hours                                           \
# race              Amer-Indian-Eskimo            Asian-Pac-Islander
# income                         <=50K       >50K              <=50K       >50K
# occupation
# Adm-clerical               37.682927  41.200000          37.254098  42.000000
# Armed-Forces                     NaN        NaN                NaN        NaN
# Craft-repair               42.414634  47.222222          39.953125  42.208333
# Exec-managerial            42.296296  42.500000          43.916667  47.588235
# Farming-fishing            48.692308        NaN          40.400000  40.000000
# Handlers-cleaners          37.500000        NaN          38.444444  48.000000
# Machine-op-inspct          40.760000  40.000000          40.708333  42.142857
# Other-service              38.020000  24.000000          36.040323  51.625000
# Priv-house-serv            35.000000        NaN          52.500000        NaN
# Prof-specialty             39.107143  46.846154          36.345133  44.727273
# Protective-serv            45.200000  40.000000          40.000000  44.400000
# Sales                      41.857143  48.750000          40.354839  48.384615
# Tech-support               37.142857  40.000000          37.600000  43.333333
# Transport-moving           47.833333  39.333333          39.500000  41.666667
#
#                                                                           \
# race                   Black                 Other                 White
# income                 <=50K       >50K      <=50K       >50K      <=50K
# occupation
# Adm-clerical       37.641026  43.180000  40.307692  40.000000  37.074560
# Armed-Forces       60.000000        NaN        NaN        NaN  37.250000
# Craft-repair       40.510823  42.692308  39.885714  40.600000  41.736842
# Exec-managerial    42.369942  45.568421  34.666667  48.333333  42.786486
# Farming-fishing    40.500000        NaN  45.076923        NaN  46.327019
# Handlers-cleaners  38.020833  40.000000  38.416667        NaN  37.342167
# Machine-op-inspct  39.904290  39.625000  38.277778  40.000000  40.471454
# Other-service      35.808411  40.722222  37.184211  40.000000  33.861901
# Priv-house-serv    28.052632        NaN  38.333333        NaN  34.034483
# Prof-specialty     37.802885  43.519481  39.769231  47.083333  40.517287
# Protective-serv    39.707865  45.076923  40.800000  40.000000  41.834862
# Sales              34.362205  48.741935  36.913043  50.000000  38.596946
# Tech-support       38.777778  42.785714  38.833333        NaN  38.713860
# Transport-moving   41.864130  44.500000  43.000000  50.000000  44.021310
#
#
# race
# income                  >50K
# occupation
# Adm-clerical       40.351711
# Armed-Forces       46.000000
# Craft-repair       44.747024
# Exec-managerial    47.361742
# Farming-fishing    54.522388
# Handlers-cleaners  42.465347
# Machine-op-inspct  43.539062
# Other-service      41.902439
# Priv-house-serv    35.000000
# Prof-specialty     45.108354
# Protective-serv    45.780952
# Sales              47.463063
# Tech-support       42.228669
# Transport-moving   49.186246

# %% [markdown]
# ------------------------------------

# %% [markdown]
# ### 📖 Groupby Object

# %% [markdown]
# The pandas library’s GroupBy object is a storage container for grouping DataFrame rows into buckets. It provides a set of methods to aggregate and analyze each independent group in the collection. It allows us to extract rows at specific index positions within each group. It also offers a convenient way to iterate over the groups of rows. There’s lots of power packed into a GroupBy object, so let’s see what it’s capable of doing.
#
# #### 💭 Questions
# - 1- calculate `max` and `min` of features for each `gender` and `income`. Which gender has the maximum avarage per hour income?
# - 2- calculate `mean` and `count` of `age` for each `gender` and `income`. Can you see any relationship between these three parameters (`age`, `gender` and `income`)?
# - 3- (Bonus) for all persons with `white` race or `Adm-clerical` Occupation and all educations except `11th`, calculate `mean` and `median` for each `gender` and `income`.

# %%
# 1
gender_income = df.groupby(by=['gender', 'income'])
gender_income.min()
# Out:
#                 age    workclass   fnlwgt education  educational-num  \
# gender income
# Female <=50K   17.0  Federal-gov  19395.0      10th              1.0
#        >50K    19.0  Federal-gov  19678.0      10th              3.0
# Male   <=50K   17.0  Federal-gov  13492.0      10th              1.0
#        >50K    20.0  Federal-gov  13769.0      10th              1.0
#
#                  occupation   relationship                race  capital-gain  \
# gender income
# Female <=50K   Adm-clerical        Husband  Amer-Indian-Eskimo           0.0
#        >50K    Adm-clerical  Not-in-family  Amer-Indian-Eskimo           0.0
# Male   <=50K   Adm-clerical        Husband  Amer-Indian-Eskimo           0.0
#        >50K    Adm-clerical        Husband  Amer-Indian-Eskimo           0.0
#
#                capital-loss  hours native-country  age_category  \
# gender income
# Female <=50K            0.0    1.0       Cambodia             1
#        >50K             0.0    2.0       Cambodia             1
# Male   <=50K            0.0    1.0       Cambodia             1
#        >50K             0.0    1.0       Cambodia             2
#
#                hours_in_year  income_values  average_hour_income
# gender income
# Female <=50K            57.0          50000           505.050505
#        >50K            114.0          50000           505.050505
# Male   <=50K            57.0          50000           505.050505
#        >50K             57.0          50000           505.050505

# %%
gender_income.max()
# Out:
#                 age    workclass     fnlwgt     education  educational-num  \
# gender income
# Female <=50K   90.0  Without-pay  1210504.0  Some-college             16.0
#        >50K    90.0  Without-pay   764638.0  Some-college             16.0
# Male   <=50K   90.0  Without-pay  1490400.0  Some-college             16.0
#        >50K    90.0  Without-pay  1097453.0  Some-college             16.0
#
#                      occupation relationship   race  capital-gain  \
# gender income
# Female <=50K   Transport-moving         Wife  White       34095.0
#        >50K    Transport-moving         Wife  White       99999.0
# Male   <=50K   Transport-moving    Unmarried  White       41310.0
#        >50K    Transport-moving         Wife  White       99999.0
#
#                capital-loss  hours native-country  age_category  \
# gender income
# Female <=50K         4356.0   99.0     Yugoslavia             4
#        >50K          3683.0   99.0     Yugoslavia             4
# Male   <=50K         3770.0   99.0     Yugoslavia             4
#        >50K          3004.0   99.0     Yugoslavia             4
#
#                hours_in_year  income_values  average_hour_income
# gender income
# Female <=50K          5643.0          50000              50000.0
#        >50K           5643.0          50000              25000.0
# Male   <=50K          5643.0          50000              50000.0
#        >50K           5643.0          50000              50000.0

# %%
# 2
gender_income_age = df[['age', 'gender', 'income']].groupby(by=['gender', 'income'])
gender_income_age.mean()
# Out:
#                      age
# gender income
# Female <=50K   36.309140
#        >50K    42.060493
# Male   <=50K   36.989782
#        >50K    44.271105

# %%
gender_income_age.count()
# Out:
#                  age
# gender income
# Female <=50K   10471
#        >50K     1339
# Male   <=50K   17029
#        >50K     7735

# %%
# 3(Bonus)
filtered = df[((df.race == 'White') | (df.occupation == 'Adm-clerical')) & (df.education != '11th')]
gb_filtered = filtered.groupby(by=['income', 'gender'])
gb_filtered.median()
# Out:
#                 age    fnlwgt  educational-num  capital-gain  capital-loss  \
# income gender
# <=50K  Female  34.0  175690.0             10.0           0.0           0.0
#        Male    35.0  179232.5              9.0           0.0           0.0
# >50K   Female  41.0  172953.5             13.0           0.0           0.0
#        Male    44.0  176912.0             12.0           0.0           0.0
#
#                hours  age_category  hours_in_year  income_values  \
# income gender
# <=50K  Female   40.0           3.0         2280.0        50000.0
#        Male     40.0           3.0         2280.0        50000.0
# >50K   Female   40.0           4.0         2280.0        50000.0
#        Male     45.0           4.0         2565.0        50000.0
#
#                average_hour_income
# income gender
# <=50K  Female          1250.000000
#        Male            1250.000000
# >50K   Female          1250.000000
#        Male            1111.111111

# %%
gb_filtered.mean()
# Out:
#                      age         fnlwgt  educational-num  capital-gain  \
# income gender
# <=50K  Female  36.421004  183057.892886        10.080219    134.465130
#        Male    37.336333  189168.322171         9.631575    174.752058
# >50K   Female  42.027825  183994.462901        11.882799   4070.305228
#        Male    44.319131  187896.929176        11.596783   3858.009876
#
#                capital-loss      hours  age_category  hours_in_year  \
# income gender
# <=50K  Female     49.023635  36.638258      2.915240    2088.380720
#        Male       61.453188  41.704200      3.009558    2377.139389
# >50K   Female    180.670320  41.057336      3.439292    2340.268128
#        Male      195.333945  46.509170      3.587613    2651.022714
#
#                income_values  average_hour_income
# income gender
# <=50K  Female        50000.0          1663.894040
#        Male          50000.0          1377.752819
# >50K   Female        50000.0          1441.629968
#        Male          50000.0          1164.126608

# %% [markdown]
# -------------------------

# %% [markdown]
# ### 📖 Merge and Join
# Pandas provide various facilities for easily combining Series or DataFrame with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# Both join and merge can be used to combine two dataframes but the join method combines two dataframes on the basis of their indexes whereas the merge method is more versatile and allows us to specify columns beside the index to join on for both dataframes.
#
# #### 💭 Questions
# - Let’s first create two dataframes to show the effect of the two methods.

# %% [markdown]
# Dataframe1:

# %% [markdown]
# | id | ML | RL | Bigdata |
# | :- | -: | :-: | :-: |
# | 81010 | 20 | 16 | 19
# | 81011 | 18.5 | 20 | 14
# | 81012 | 15 | 19.6 | 19.5
# | 81013 | 19.9 | 19.49 | 19

# %% [markdown]
# Dataframe2:

# %% [markdown]
# | id | GPA | UNI |
# | :- | -: | :-: |
# | 81011 | 19 | T0
# | 81012 | 18.5 | T1
# | 81013 | 17 | T2
# | 81014 | 19.9 | T5
# | 81015 | 20 | T3

# %% [markdown]
# **Write the answer below:**

# %%
# create DFs
df1_dict = {
    'id': [81010, 81011, 81012, 81013],
    'ML': [20, 18.5, 15, 19.5],
    'RL': [16, 20, 19.6, 19.49],
    'Bigdata': [19, 14, 19.5, 19]
}

df2_dict = {
    'id': [81011, 81012, 81013, 81014, 81015],
    'GPA': [19, 18.5, 17, 19.9, 20],
    'UNI': ['T0', 'T1', 'T2', 'T5', 'T3'],
}

df1 = pd.DataFrame(df1_dict)
df2 = pd.DataFrame(df2_dict)

df1
# Out:
#       id    ML     RL  Bigdata
# 0  81010  20.0  16.00     19.0
# 1  81011  18.5  20.00     14.0
# 2  81012  15.0  19.60     19.5
# 3  81013  19.5  19.49     19.0

# %%
df2
# Out:
#       id   GPA UNI
# 0  81011  19.0  T0
# 1  81012  18.5  T1
# 2  81013  17.0  T2
# 3  81014  19.9  T5
# 4  81015  20.0  T3

# %% [markdown]
# #### 💭 Questions
# - merge two dataframe based on `id` columns. (the default mode or `how` parameter of this method is `inner`)
# - merge two dataframes based on the `id` columns and `Outer` mode
# - (Bonus) merge two dataframes based `id` columns and `left` and `right` mode
# - (Bonus) what's the difference Between `inner` and `outer` mode? write your answer in a markdown cell

# %% [markdown]
# **Write the answer below:**

# %%
# inner merge on id
pd.merge(df1, df2, on='id')
# Out:
#       id    ML     RL  Bigdata   GPA UNI
# 0  81011  18.5  20.00     14.0  19.0  T0
# 1  81012  15.0  19.60     19.5  18.5  T1
# 2  81013  19.5  19.49     19.0  17.0  T2

# %%
# outer merge on id
pd.merge(df1, df2, on='id', how='outer')
# Out:
#       id    ML     RL  Bigdata   GPA  UNI
# 0  81010  20.0  16.00     19.0   NaN  NaN
# 1  81011  18.5  20.00     14.0  19.0   T0
# 2  81012  15.0  19.60     19.5  18.5   T1
# 3  81013  19.5  19.49     19.0  17.0   T2
# 4  81014   NaN    NaN      NaN  19.9   T5
# 5  81015   NaN    NaN      NaN  20.0   T3

# %%
# (Bonus) left and right merge
inner_megre = pd.merge(df1, df2, on='id', how='left')
outter_merge = pd.merge(df1, df2, on='id', how='right')
inner_megre
# Out:
#       id    ML     RL  Bigdata   GPA  UNI
# 0  81010  20.0  16.00     19.0   NaN  NaN
# 1  81011  18.5  20.00     14.0  19.0   T0
# 2  81012  15.0  19.60     19.5  18.5   T1
# 3  81013  19.5  19.49     19.0  17.0   T2

# %%
outter_merge
# Out:
#       id    ML     RL  Bigdata   GPA UNI
# 0  81011  18.5  20.00     14.0  19.0  T0
# 1  81012  15.0  19.60     19.5  18.5  T1
# 2  81013  19.5  19.49     19.0  17.0  T2
# 3  81014   NaN    NaN      NaN  19.9  T5
# 4  81015   NaN    NaN      NaN  20.0  T3

# %% [markdown]
# (Bonus) difference of inner and outer

# %% [markdown]
# #### 💭 Questions
# - join dataframe1 with dataframe2
# - join dataframe1 with dataframe2 on the `id` column
# (hint) you need to set the id column as an index column.

# %% [markdown]
# **Write the answer below:**

# %%
# join two dataframes
df1.join(df2, lsuffix='_caller', rsuffix='_other')
# Out:
#    id_caller    ML     RL  Bigdata  id_other   GPA UNI
# 0      81010  20.0  16.00     19.0     81011  19.0  T0
# 1      81011  18.5  20.00     14.0     81012  18.5  T1
# 2      81012  15.0  19.60     19.5     81013  17.0  T2
# 3      81013  19.5  19.49     19.0     81014  19.9  T5

# %%
# join based on id column
df1 = df1.set_index('id')
df2 = df2.set_index('id')
df1.join(df2, on='id')
# Out:
#          ML     RL  Bigdata   GPA  UNI
# id
# 81010  20.0  16.00     19.0   NaN  NaN
# 81011  18.5  20.00     14.0  19.0   T0
# 81012  15.0  19.60     19.5  18.5   T1
# 81013  19.5  19.49     19.0  17.0   T2

# %% [markdown]
# # Good Luck 😉

# %% [markdown]
# # Reference:
# - Pandas in Action, Boris Paskhaver, Manning Publication.
